# %%
import pandas as pd

# %%
#___Excel_keandar _multiple sheet ko import kana 

df = pd.read_excel(r"C:\Users\rahul\Downloads\PizzaSales.xlsx")
df
# Out:
#     Unnamed: 0           Unnamed: 1     Unnamed: 2 Unnamed: 3  Unnamed: 4  \
# 0          NaN                 Date     Pizza_Name   Category  Pizza_Code
# 1          NaN  2023-01-01 00:00:00         Deluxe    Non-Veg           4
# 2          NaN  2023-01-01 00:00:00  Double Cheese        Veg           5
# 3          NaN  2023-01-01 00:00:00      Farmhouse        Veg           3
# 4          NaN  2023-01-02 00:00:00         Deluxe    Non-Veg           4
# 5          NaN  2023-01-02 00:00:00  Double Cheese        Veg           5
# 6          NaN  2023-01-03 00:00:00        Chicago    Non-Veg           2
# 7          NaN  2023-01-03 00:00:00  Double Cheese        Veg           5
# 8          NaN  2023-01-03 00:00:00      Farmhouse        Veg           3
# 9          NaN  2023-01-04 00:00:00      Farmhouse        Veg           3
# 10         NaN  2023-01-05 00:00:00        Chicago    Non-Veg           2
# 11         NaN  2023-01-05 00:00:00     Margherita        Veg           1
#
# ...

# %%
df1 = pd.read_excel(r"C:\Users\rahul\Downloads\PizzaSales.xlsx","Sheet2")
df1
# Out:
#   2023-01-01 00:00:00  Non-Veg  4  15   7
# 0          2023-01-01      Veg  5   9   9
# 1          2023-01-01      Veg  3   7  23
# 2          2023-01-02  Non-Veg  4  15   9
# 3          2023-01-02      Veg  5   9  21
# 4          2023-01-03  Non-Veg  2  10   1
# 5          2023-01-03      Veg  5   9   4
# 6          2023-01-03      Veg  3   7  22
# 7          2023-01-04      Veg  3   7   7
# 8          2023-01-05  Non-Veg  2  10  11
# 9          2023-01-05      Veg  1   8  11

# %%
pip install pymysql
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import pymysql as sql

# %%
db=sql.connect(host='localhost',user='root',password='Arun@7838@83',db='rkraj')

# %%
df2=pd.read_sql_query("select * from empoly ;",db)

df2
# Out:
# C:\Users\rahul\AppData\Local\Temp\ipykernel_25608\3675222037.py:1: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   df2=pd.read_sql_query("select * from empoly ;",db)
#       id     name lastname  age  salary    contact E_Mail
# 0   1010    rahul    singh   22   25000        NaN   None
# 1   1012    tarun   sharma   35   35000        NaN   None
# 2   1014     esha   chadda   30   40000        NaN   None
# 3   1016     aman   sharma   50   25000        NaN   None
# 4   1020     amar   khuran   30   60000        NaN   None
# 5   1018     monu   gautam   40   40000        NaN   None
# 6   1022    harsh   sharma   28   65000        NaN   None
# 7   1022    bunty    singh   20   20000        NaN   None
# 8   2020   deepak   sharma   20   25000   121145.0   None
# 9   2022  sandeep  chauhan   35   30000  1212546.0   None
# ...

# %%
df2.head(2)
# Out:
#      id   name lastname  age  salary  contact E_Mail
# 0  1010  rahul    singh   22   25000      NaN   None
# 1  1012  tarun   sharma   35   35000      NaN   None

# %%
df2.tail(2)
# Out:
#       id   name lastname  age  salary    contact E_Mail
# 10  2028   sonu   chadda   45   45000  1211435.0   None
# 11  2026  harsh  chauhan   45   65000  1213645.0   None

# %%
# kis basepar karna hai 

df2.sort_values("salary")
# Out:
#       id     name lastname  age  salary    contact E_Mail
# 7   1022    bunty    singh   20   20000        NaN   None
# 0   1010    rahul    singh   22   25000        NaN   None
# 3   1016     aman   sharma   50   25000        NaN   None
# 8   2020   deepak   sharma   20   25000   121145.0   None
# 9   2022  sandeep  chauhan   35   30000  1212546.0   None
# 1   1012    tarun   sharma   35   35000        NaN   None
# 2   1014     esha   chadda   30   40000        NaN   None
# 5   1018     monu   gautam   40   40000        NaN   None
# 10  2028     sonu   chadda   45   45000  1211435.0   None
# 4   1020     amar   khuran   30   60000        NaN   None
# 6   1022    harsh   sharma   28   65000        NaN   None
# 11  2026    harsh  chauhan   45   65000  1213645.0   None

# %%
# kis basepar karna hai 

df2.sort_values("age")
# Out:
#       id     name lastname  age  salary    contact E_Mail
# 7   1022    bunty    singh   20   20000        NaN   None
# 8   2020   deepak   sharma   20   25000   121145.0   None
# 0   1010    rahul    singh   22   25000        NaN   None
# 6   1022    harsh   sharma   28   65000        NaN   None
# 2   1014     esha   chadda   30   40000        NaN   None
# 4   1020     amar   khuran   30   60000        NaN   None
# 1   1012    tarun   sharma   35   35000        NaN   None
# 9   2022  sandeep  chauhan   35   30000  1212546.0   None
# 5   1018     monu   gautam   40   40000        NaN   None
# 10  2028     sonu   chadda   45   45000  1211435.0   None
# 11  2026    harsh  chauhan   45   65000  1213645.0   None
# 3   1016     aman   sharma   50   25000        NaN   None

# %%
# kis basepar karna hai 

df2.sort_values("salary",ascending=False)
# Out:
#       id     name lastname  age  salary    contact E_Mail
# 6   1022    harsh   sharma   28   65000        NaN   None
# 11  2026    harsh  chauhan   45   65000  1213645.0   None
# 4   1020     amar   khuran   30   60000        NaN   None
# 10  2028     sonu   chadda   45   45000  1211435.0   None
# 2   1014     esha   chadda   30   40000        NaN   None
# 5   1018     monu   gautam   40   40000        NaN   None
# 1   1012    tarun   sharma   35   35000        NaN   None
# 9   2022  sandeep  chauhan   35   30000  1212546.0   None
# 0   1010    rahul    singh   22   25000        NaN   None
# 3   1016     aman   sharma   50   25000        NaN   None
# 8   2020   deepak   sharma   20   25000   121145.0   None
# 7   1022    bunty    singh   20   20000        NaN   None

# %%
# Kisi person ki sabse jada salary 

df2.sort_values("salary",ascending=False).head(1)
# Out:
#      id   name lastname  age  salary  contact E_Mail
# 6  1022  harsh   sharma   28   65000      NaN   None

# %%
df2
# Out:
#       id     name lastname  age  salary    contact E_Mail
# 0   1010    rahul    singh   22   25000        NaN   None
# 1   1012    tarun   sharma   35   35000        NaN   None
# 2   1014     esha   chadda   30   40000        NaN   None
# 3   1016     aman   sharma   50   25000        NaN   None
# 4   1020     amar   khuran   30   60000        NaN   None
# 5   1018     monu   gautam   40   40000        NaN   None
# 6   1022    harsh   sharma   28   65000        NaN   None
# 7   1022    bunty    singh   20   20000        NaN   None
# 8   2020   deepak   sharma   20   25000   121145.0   None
# 9   2022  sandeep  chauhan   35   30000  1212546.0   None
# 10  2028     sonu   chadda   45   45000  1211435.0   None
# 11  2026    harsh  chauhan   45   65000  1213645.0   None

# %%
#  salary ke behalf par Rank nikalo
df2['Rank']=df2['salary'].rank(ascending=False).astype('int')  
                                                           # """salary_with_rank?"""

df2
# Out:
#       id     name lastname  age  salary    contact E_Mail  Rank
# 0   1010    rahul    singh   22   25000        NaN   None    10
# 1   1012    tarun   sharma   35   35000        NaN   None     7
# 2   1014     esha   chadda   30   40000        NaN   None     5
# 3   1016     aman   sharma   50   25000        NaN   None    10
# 4   1020     amar   khuran   30   60000        NaN   None     3
# 5   1018     monu   gautam   40   40000        NaN   None     5
# 6   1022    harsh   sharma   28   65000        NaN   None     1
# 7   1022    bunty    singh   20   20000        NaN   None    12
# 8   2020   deepak   sharma   20   25000   121145.0   None    10
# 9   2022  sandeep  chauhan   35   30000  1212546.0   None     8
# 10  2028     sonu   chadda   45   45000  1211435.0   None     4
# 11  2026    harsh  chauhan   45   65000  1213645.0   None     1

# %%
df2.sort_values("Rank",ascending=True)
# Out:
#       id     name lastname  age  salary    contact E_Mail  Rank
# 6   1022    harsh   sharma   28   65000        NaN   None     1
# 11  2026    harsh  chauhan   45   65000  1213645.0   None     1
# 4   1020     amar   khuran   30   60000        NaN   None     3
# 10  2028     sonu   chadda   45   45000  1211435.0   None     4
# 2   1014     esha   chadda   30   40000        NaN   None     5
# 5   1018     monu   gautam   40   40000        NaN   None     5
# 1   1012    tarun   sharma   35   35000        NaN   None     7
# 9   2022  sandeep  chauhan   35   30000  1212546.0   None     8
# 0   1010    rahul    singh   22   25000        NaN   None    10
# 3   1016     aman   sharma   50   25000        NaN   None    10
# 8   2020   deepak   sharma   20   25000   121145.0   None    10
# 7   1022    bunty    singh   20   20000        NaN   None    12

# %%
df2.sort_values('salary',ascending=False)
# Out:
#       id     name lastname  age  salary    contact E_Mail  Rank
# 6   1022    harsh   sharma   28   65000        NaN   None     1
# 11  2026    harsh  chauhan   45   65000  1213645.0   None     1
# 4   1020     amar   khuran   30   60000        NaN   None     3
# 10  2028     sonu   chadda   45   45000  1211435.0   None     4
# 2   1014     esha   chadda   30   40000        NaN   None     5
# 5   1018     monu   gautam   40   40000        NaN   None     5
# 1   1012    tarun   sharma   35   35000        NaN   None     7
# 9   2022  sandeep  chauhan   35   30000  1212546.0   None     8
# 0   1010    rahul    singh   22   25000        NaN   None    10
# 3   1016     aman   sharma   50   25000        NaN   None    10
# 8   2020   deepak   sharma   20   25000   121145.0   None    10
# 7   1022    bunty    singh   20   20000        NaN   None    12

# %%
#___Update_Values

# %%
df2['Denserank']=df2['salary'].rank(method='dense',ascending=False).astye('int')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_25608\2012969442.py in ?()
# ----> 1 df2['Denserank']=df2['salary'].rank(method='dense',ascending=False).astye('int')
#
# C:\ProgramData\anaconda3\Lib\site-packages\pandas\core\generic.py in ?(self, name)
#    5985             and name not in self._accessors
#    5986             and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    5987         ):
#    5988             return self[name]
# -> 5989         return object.__getattribute__(self, name)
#
# AttributeError: 'Series' object has no attribute 'astye'

# %%
df2
# Out:
#       id     name lastname  age  salary    contact E_Mail  Rank
# 0   1010    rahul    singh   22   25000        NaN   None    10
# 1   1012    tarun   sharma   35   35000        NaN   None     7
# 2   1014     esha   chadda   30   40000        NaN   None     5
# 3   1016     aman   sharma   50   25000        NaN   None    10
# 4   1020     amar   khuran   30   60000        NaN   None     3
# 5   1018     monu   gautam   40   40000        NaN   None     5
# 6   1022    harsh   sharma   28   65000        NaN   None     1
# 7   1022    bunty    singh   20   20000        NaN   None    12
# 8   2020   deepak   sharma   20   25000   121145.0   None    10
# 9   2022  sandeep  chauhan   35   30000  1212546.0   None     8
# 10  2028     sonu   chadda   45   45000  1211435.0   None     4
# 11  2026    harsh  chauhan   45   65000  1213645.0   None     1

# %%
df2.sort_values(['salary','name'],ascending=[False,True])
# Out:
#       id     name lastname  age  salary    contact E_Mail  Rank
# 6   1022    harsh   sharma   28   65000        NaN   None     1
# 11  2026    harsh  chauhan   45   65000  1213645.0   None     1
# 4   1020     amar   khuran   30   60000        NaN   None     3
# 10  2028     sonu   chadda   45   45000  1211435.0   None     4
# 2   1014     esha   chadda   30   40000        NaN   None     5
# 5   1018     monu   gautam   40   40000        NaN   None     5
# 1   1012    tarun   sharma   35   35000        NaN   None     7
# 9   2022  sandeep  chauhan   35   30000  1212546.0   None     8
# 3   1016     aman   sharma   50   25000        NaN   None    10
# 8   2020   deepak   sharma   20   25000   121145.0   None    10
# 0   1010    rahul    singh   22   25000        NaN   None    10
# 7   1022    bunty    singh   20   20000        NaN   None    12

# %%
k=[3,4,5,6,4,5,8,9,5,3,99,74]

# %%
df2['Add_Columns']=k

# %%
df2
# Out:
#       id     name lastname  age  salary    contact E_Mail  Rank  Add_Columns
# 0   1010    rahul    singh   22   25000        NaN   None    10            3
# 1   1012    tarun   sharma   35   35000        NaN   None     7            4
# 2   1014     esha   chadda   30   40000        NaN   None     5            5
# 3   1016     aman   sharma   50   25000        NaN   None    10            6
# 4   1020     amar   khuran   30   60000        NaN   None     3            4
# 5   1018     monu   gautam   40   40000        NaN   None     5            5
# 6   1022    harsh   sharma   28   65000        NaN   None     1            8
# 7   1022    bunty    singh   20   20000        NaN   None    12            9
# 8   2020   deepak   sharma   20   25000   121145.0   None    10            5
# 9   2022  sandeep  chauhan   35   30000  1212546.0   None     8            3
# 10  2028     sonu   chadda   45   45000  1211435.0   None     4           99
# ...

# %%
df2['Taxsala']=df2['salary']*df2['Tax']/100
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File C:\ProgramData\anaconda3\Lib\site-packages\pandas\core\indexes\base.py:3653, in Index.get_loc(self, key)
#    3652 try:
# -> 3653     return self._engine.get_loc(casted_key)
#    3654 except KeyError as err:
#
# File C:\ProgramData\anaconda3\Lib\site-packages\pandas\_libs\index.pyx:147, in pandas._libs.index.IndexEngine.get_loc()
#
# File C:\ProgramData\anaconda3\Lib\site-packages\pandas\_libs\index.pyx:176, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\_libs\hashtable_class_helper.pxi:7080, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\_libs\hashtable_class_helper.pxi:7088, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Tax'
#
# The above exception was the direct cause of the following exception:
#
# ...

# %%
df2
# Out:
#       id     name lastname  age  salary    contact E_Mail  Rank  Add_Columns
# 0   1010    rahul    singh   22   25000        NaN   None    10            3
# 1   1012    tarun   sharma   35   35000        NaN   None     7            4
# 2   1014     esha   chadda   30   40000        NaN   None     5            5
# 3   1016     aman   sharma   50   25000        NaN   None    10            6
# 4   1020     amar   khuran   30   60000        NaN   None     3            4
# 5   1018     monu   gautam   40   40000        NaN   None     5            5
# 6   1022    harsh   sharma   28   65000        NaN   None     1            8
# 7   1022    bunty    singh   20   20000        NaN   None    12            9
# 8   2020   deepak   sharma   20   25000   121145.0   None    10            5
# 9   2022  sandeep  chauhan   35   30000  1212546.0   None     8            3
# 10  2028     sonu   chadda   45   45000  1211435.0   None     4           99
# ...

# %%
df2['Basic_Salary']=df2['salary']-df2['Taxsala']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File C:\ProgramData\anaconda3\Lib\site-packages\pandas\core\indexes\base.py:3653, in Index.get_loc(self, key)
#    3652 try:
# -> 3653     return self._engine.get_loc(casted_key)
#    3654 except KeyError as err:
#
# File C:\ProgramData\anaconda3\Lib\site-packages\pandas\_libs\index.pyx:147, in pandas._libs.index.IndexEngine.get_loc()
#
# File C:\ProgramData\anaconda3\Lib\site-packages\pandas\_libs\index.pyx:176, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\_libs\hashtable_class_helper.pxi:7080, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\_libs\hashtable_class_helper.pxi:7088, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Taxsala'
#
# The above exception was the direct cause of the following exception:
#
# ...

# %%
df2
# Out:
#       id     name lastname  age  salary    contact E_Mail  Rank  Add_Columns
# 0   1010    rahul    singh   22   25000        NaN   None    10            3
# 1   1012    tarun   sharma   35   35000        NaN   None     7            4
# 2   1014     esha   chadda   30   40000        NaN   None     5            5
# 3   1016     aman   sharma   50   25000        NaN   None    10            6
# 4   1020     amar   khuran   30   60000        NaN   None     3            4
# 5   1018     monu   gautam   40   40000        NaN   None     5            5
# 6   1022    harsh   sharma   28   65000        NaN   None     1            8
# 7   1022    bunty    singh   20   20000        NaN   None    12            9
# 8   2020   deepak   sharma   20   25000   121145.0   None    10            5
# 9   2022  sandeep  chauhan   35   30000  1212546.0   None     8            3
# 10  2028     sonu   chadda   45   45000  1211435.0   None     4           99
# ...

# %%
#____Export the Data /Files

# %%
df2.to_csv("d://licdata.csv")

# %%
df2
# Out:
#       id     name lastname  age  salary    contact E_Mail  Rank  Add_Columns
# 0   1010    rahul    singh   22   25000        NaN   None    10            3
# 1   1012    tarun   sharma   35   35000        NaN   None     7            4
# 2   1014     esha   chadda   30   40000        NaN   None     5            5
# 3   1016     aman   sharma   50   25000        NaN   None    10            6
# 4   1020     amar   khuran   30   60000        NaN   None     3            4
# 5   1018     monu   gautam   40   40000        NaN   None     5            5
# 6   1022    harsh   sharma   28   65000        NaN   None     1            8
# 7   1022    bunty    singh   20   20000        NaN   None    12            9
# 8   2020   deepak   sharma   20   25000   121145.0   None    10            5
# 9   2022  sandeep  chauhan   35   30000  1212546.0   None     8            3
# 10  2028     sonu   chadda   45   45000  1211435.0   None     4           99
# ...

# %%
df2.head(2)
# Out:
#      id   name lastname  age  salary  contact E_Mail  Rank  Add_Columns
# 0  1010  rahul    singh   22   25000      NaN   None    10            3
# 1  1012  tarun   sharma   35   35000      NaN   None     7            4

# %% [markdown]
# # Drop_Columns

# %%
df2.drop(['Tax','Add_Columns','E_Mail'],axis=1)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[33], line 1
# ----> 1 df2.drop(['Tax','Add_Columns','E_Mail'],axis=1)
#
# File C:\ProgramData\anaconda3\Lib\site-packages\pandas\core\frame.py:5258, in DataFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    5110 def drop(
#    5111     self,
#    5112     labels: IndexLabel = None,
#    (...)
#    5119     errors: IgnoreRaise = "raise",
#    5120 ) -> DataFrame | None:
#    5121     """
#    5122     Drop specified labels from rows or columns.
#    5123
#    (...)
#    5256             weight  1.0     0.8
#    5257     """
# -> 5258     return super().drop(
#    5259         labels=labels,
#    5260         axis=axis,
#    5261         index=index,
#    5262         columns=columns,
#    5263         level=level,
#    5264         inplace=inplace,
#    5265         errors=errors,
#    5266     )
#
# ...

# %%
df2.head(2)
# Out:
#      id   name lastname  age  salary  contact E_Mail  Rank  Add_Columns
# 0  1010  rahul    singh   22   25000      NaN   None    10            3
# 1  1012  tarun   sharma   35   35000      NaN   None     7            4

# %% [markdown]
# # _Row   delete

# %%
df2.drop([2,5,8,6],axis=0)
# Out:
#       id     name lastname  age  salary    contact E_Mail  Rank  Add_Columns
# 0   1010    rahul    singh   22   25000        NaN   None    10            3
# 1   1012    tarun   sharma   35   35000        NaN   None     7            4
# 3   1016     aman   sharma   50   25000        NaN   None    10            6
# 4   1020     amar   khuran   30   60000        NaN   None     3            4
# 7   1022    bunty    singh   20   20000        NaN   None    12            9
# 9   2022  sandeep  chauhan   35   30000  1212546.0   None     8            3
# 10  2028     sonu   chadda   45   45000  1211435.0   None     4           99
# 11  2026    harsh  chauhan   45   65000  1213645.0   None     1           74

# %%
df2.head(2)
# Out:
#      id   name lastname  age  salary  contact E_Mail  Rank  Add_Columns
# 0  1010  rahul    singh   22   25000      NaN   None    10            3
# 1  1012  tarun   sharma   35   35000      NaN   None     7            4

# %%
df2
# Out:
#       id     name lastname  age  salary    contact E_Mail  Rank  Add_Columns
# 0   1010    rahul    singh   22   25000        NaN   None    10            3
# 1   1012    tarun   sharma   35   35000        NaN   None     7            4
# 2   1014     esha   chadda   30   40000        NaN   None     5            5
# 3   1016     aman   sharma   50   25000        NaN   None    10            6
# 4   1020     amar   khuran   30   60000        NaN   None     3            4
# 5   1018     monu   gautam   40   40000        NaN   None     5            5
# 6   1022    harsh   sharma   28   65000        NaN   None     1            8
# 7   1022    bunty    singh   20   20000        NaN   None    12            9
# 8   2020   deepak   sharma   20   25000   121145.0   None    10            5
# 9   2022  sandeep  chauhan   35   30000  1212546.0   None     8            3
# 10  2028     sonu   chadda   45   45000  1211435.0   None     4           99
# ...

# %% [markdown]
# # _Transform

# %%
df2.T
# Out:
#                 0       1       2       3       4       5       6      7   \
# id            1010    1012    1014    1016    1020    1018    1022   1022
# name         rahul   tarun    esha    aman    amar    monu   harsh  bunty
# lastname     singh  sharma  chadda  sharma  khuran  gautam  sharma  singh
# age             22      35      30      50      30      40      28     20
# salary       25000   35000   40000   25000   60000   40000   65000  20000
# contact        NaN     NaN     NaN     NaN     NaN     NaN     NaN    NaN
# E_Mail        None    None    None    None    None    None    None   None
# Rank            10       7       5      10       3       5       1     12
# Add_Columns      3       4       5       6       4       5       8      9
#
#                    8          9          10         11
# id               2020       2022       2028       2026
# name           deepak    sandeep       sonu      harsh
# lastname       sharma    chauhan     chadda    chauhan
# ...

# %%
df2
# Out:
#       id     name lastname  age  salary    contact E_Mail  Rank  Add_Columns
# 0   1010    rahul    singh   22   25000        NaN   None    10            3
# 1   1012    tarun   sharma   35   35000        NaN   None     7            4
# 2   1014     esha   chadda   30   40000        NaN   None     5            5
# 3   1016     aman   sharma   50   25000        NaN   None    10            6
# 4   1020     amar   khuran   30   60000        NaN   None     3            4
# 5   1018     monu   gautam   40   40000        NaN   None     5            5
# 6   1022    harsh   sharma   28   65000        NaN   None     1            8
# 7   1022    bunty    singh   20   20000        NaN   None    12            9
# 8   2020   deepak   sharma   20   25000   121145.0   None    10            5
# 9   2022  sandeep  chauhan   35   30000  1212546.0   None     8            3
# 10  2028     sonu   chadda   45   45000  1211435.0   None     4           99
# ...

# %%
df2
# Out:
#       id     name lastname  age  salary    contact E_Mail  Rank  Add_Columns
# 0   1010    rahul    singh   22   25000        NaN   None    10            3
# 1   1012    tarun   sharma   35   35000        NaN   None     7            4
# 2   1014     esha   chadda   30   40000        NaN   None     5            5
# 3   1016     aman   sharma   50   25000        NaN   None    10            6
# 4   1020     amar   khuran   30   60000        NaN   None     3            4
# 5   1018     monu   gautam   40   40000        NaN   None     5            5
# 6   1022    harsh   sharma   28   65000        NaN   None     1            8
# 7   1022    bunty    singh   20   20000        NaN   None    12            9
# 8   2020   deepak   sharma   20   25000   121145.0   None    10            5
# 9   2022  sandeep  chauhan   35   30000  1212546.0   None     8            3
# 10  2028     sonu   chadda   45   45000  1211435.0   None     4           99
# ...

# %%
df2[~df2['name'].isin(['ravi','aman','monu','bunty'])]
# Out:
#       id     name lastname  age  salary    contact E_Mail  Rank  Add_Columns
# 0   1010    rahul    singh   22   25000        NaN   None    10            3
# 1   1012    tarun   sharma   35   35000        NaN   None     7            4
# 2   1014     esha   chadda   30   40000        NaN   None     5            5
# 4   1020     amar   khuran   30   60000        NaN   None     3            4
# 6   1022    harsh   sharma   28   65000        NaN   None     1            8
# 8   2020   deepak   sharma   20   25000   121145.0   None    10            5
# 9   2022  sandeep  chauhan   35   30000  1212546.0   None     8            3
# 10  2028     sonu   chadda   45   45000  1211435.0   None     4           99
# 11  2026    harsh  chauhan   45   65000  1213645.0   None     1           74

# %%
df2
# Out:
#       id     name lastname  age  salary    contact E_Mail  Rank  Add_Columns
# 0   1010    rahul    singh   22   25000        NaN   None    10            3
# 1   1012    tarun   sharma   35   35000        NaN   None     7            4
# 2   1014     esha   chadda   30   40000        NaN   None     5            5
# 3   1016     aman   sharma   50   25000        NaN   None    10            6
# 4   1020     amar   khuran   30   60000        NaN   None     3            4
# 5   1018     monu   gautam   40   40000        NaN   None     5            5
# 6   1022    harsh   sharma   28   65000        NaN   None     1            8
# 7   1022    bunty    singh   20   20000        NaN   None    12            9
# 8   2020   deepak   sharma   20   25000   121145.0   None    10            5
# 9   2022  sandeep  chauhan   35   30000  1212546.0   None     8            3
# 10  2028     sonu   chadda   45   45000  1211435.0   None     4           99
# ...
